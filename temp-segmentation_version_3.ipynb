# %%
import numpy as np
import os
import tensorflow as tf
import cv2
import json
import matplotlib.pyplot as plt

print("Hello world.")
# Out:
# 2025-09-25 14:26:48.562918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758810408.788503      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758810408.857018      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Hello world.

# %%
image_path = r"/kaggle/input/malabar-dataset/Malabar_Dataset/Bacterial-Spot(752)/Bacterial-Spot (1).jpg"
image = cv2.imread(image_path)

json_path = r"/kaggle/input/temp-dataset/annotated_json_files/Bacterial-Spot(752)/affected_region/Bacterial-Spot (1).json"
with open(json_path, 'r') as file:
    data = json.load(file)

# Create a blank mask with the same dimensions as the input image
mask = np.zeros(image.shape[:2], dtype=np.uint8)

if 'shapes' in data:
    for annotation in data['shapes']:
        points = np.array(annotation['points'], dtype=np.int32)
        cv2.fillPoly(mask, [points], color=255)
elif 'annotations' in data:
    for annotation in data['annotations']:
        points = np.array(annotation['points'], dtype=np.int32)
        cv2.fillPoly(mask, [points], color=255)
else:
    print("No valid keys ('shapes' or 'annotations') found in JSON.")

# Apply the mask to the original image
masked_image = cv2.bitwise_and(image, image, mask=mask)

# Display the original image, mask, and masked image
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 2)
plt.title("Mask")
plt.imshow(mask, cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Masked Image")
plt.imshow(cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB))

plt.show()

# %%
i = 0 
image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset/Bacterial-Spot(752)"
json_path = "/kaggle/input/temp-dataset/annotated_json_files/Bacterial-Spot(752)/affected_region"
for i in range(45, 50):
    image_name = "Bacterial-Spot ("+str(i+1)+").jpg"
    json_file_name = "Bacterial-Spot ("+str(i+1)+").json"
    #print(image_name)
    #print(json_file_name)
    image = cv2.imread(image_path+'/'+image_name)
    json_file = json_path + '/' + json_file_name
    #print(json_file)

    with open(json_file, 'r') as file:
        data = json.load(file)

    # Create a blank mask with the same dimensions as the input image
    mask = np.zeros(image.shape[:2], dtype=np.uint8)

    if 'shapes' in data:
        for annotation in data['shapes']:
            points = np.array(annotation['points'], dtype=np.int32)
            cv2.fillPoly(mask, [points], color=255)
    elif 'annotations' in data:
        for annotation in data['annotations']:
            points = np.array(annotation['points'], dtype=np.int32)
            cv2.fillPoly(mask, [points], color=255)
    else:
        print("No valid keys ('shapes' or 'annotations') found in JSON.")

    masked_image = cv2.bitwise_and(image, image, mask=mask)


    # Display the original image, mask, and masked image
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title("Original Image")
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    plt.subplot(1, 3, 2)
    plt.title("Mask")
    plt.imshow(mask, cmap='gray')

    plt.subplot(1, 3, 3)
    plt.title("Masked Image")
    plt.imshow(cv2.cvtColor(masked_image, cv2.COLOR_BGR2RGB))

    plt.show()

# %%
def create_mask(json_file, image_shape):
    with open(json_file, 'r') as f:
        data = json.load(f)
    
    mask = np.zeros(image_shape[:2], dtype=np.uint8)
    
    for shape in data['shapes']:
        points = np.array(shape['points'], dtype=np.int32)
        cv2.fillPoly(mask, [points], 255)
    
    return mask


train_images, valid_images, test_images = [], [], []
train_masks, valid_masks, test_masks = [], [], []

for i in range(0, 50):

    json_file_name = "Bacterial-Spot ("+str(i+1)+").json"
    json_file = json_path + '/' + json_file_name
    
    image_name = "Bacterial-Spot ("+str(i+1)+").jpg"
    image = cv2.imread(image_path+'/'+image_name)
    if image is None:
        continue
    
    mask = create_mask(json_file, image.shape)
    
    # Save mask
    #mask_path = os.path.join(mask_dir, f'mask_{i+1}.png')
    #cv2.imwrite(mask_path, mask)
    
    if i < 40:
        train_images.append(image)
        train_masks.append(mask)
    elif i < 45:
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)


print("Hello world.")
# Out:
# Hello world.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input, concatenate

def build_unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    
    u4 = UpSampling2D((2, 2))(c3)
    u4 = concatenate([u4, c2])
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(u4)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(c4)
    
    u5 = UpSampling2D((2, 2))(c4)
    u5 = concatenate([u5, c1])
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same')(u5)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same')(c5)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c5)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

unet_model = build_unet()
unet_model.summary()
# Out:
# I0000 00:00:1758810427.307864      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758810427.308556      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 128, 128,  │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 128,  │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 256, 256,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 256, 256,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         65 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,883,137 (7.18 MB)
#  Trainable params: 1,883,137 (7.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Preprocess images and masks
image_size = (256, 256)

def preprocess_data(images, masks):
    images_resized = [cv2.resize(img, image_size) for img in images]
    masks_resized = [cv2.resize(mask, image_size) for mask in masks]
    
    images_array = np.array(images_resized) / 255.0
    masks_array = np.array(masks_resized) / 255.0
    
    images_array = images_array.astype(np.float32)
    masks_array = masks_array.astype(np.float32)
    
    masks_array = np.expand_dims(masks_array, axis=-1)  # Ensure correct shape
    
    return images_array, masks_array

# Prepare datasets
X_train, y_train = preprocess_data(train_images, train_masks)
X_valid, y_valid = preprocess_data(valid_images, valid_masks)
X_test, y_test = preprocess_data(test_images, test_masks)

# Callbacks
checkpoint = ModelCheckpoint("unet_best_model.keras", monitor="val_loss", save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=40, restore_best_weights=True)

# Train the model
history = unet_model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=50,
    batch_size=8,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate on test set
test_loss, test_accuracy = unet_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758810434.047547     107 service.cc:148] XLA service 0x7f12d000baf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758810434.048515     107 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758810434.048539     107 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758810434.706145     107 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-09-25 14:27:19.017490: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k11=0} for conv (f32[8,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-25 14:27:19.109833: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.092473888s
# Trying algorithm eng12{k11=0} for conv (f32[8,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1758810460.526514     107 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6594 - loss: 0.4815
# Epoch 1: val_loss improved from inf to 0.24920, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.6910 - loss: 0.4558 - val_accuracy: 0.9937 - val_loss: 0.2492
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9969 - loss: 0.0649
# Epoch 2: val_loss improved from 0.24920 to 0.05142, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 0.9968 - loss: 0.0621 - val_accuracy: 0.9937 - val_loss: 0.0514
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9967 - loss: 0.0476
# Epoch 3: val_loss did not improve from 0.05142
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - accuracy: 0.9967 - loss: 0.0458 - val_accuracy: 0.9937 - val_loss: 0.0583
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9965 - loss: 0.0322
# Epoch 4: val_loss improved from 0.05142 to 0.04574, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.9965 - loss: 0.0320 - val_accuracy: 0.9937 - val_loss: 0.0457
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9964 - loss: 0.0262
# Epoch 5: val_loss improved from 0.04574 to 0.03274, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 0.9965 - loss: 0.0259 - val_accuracy: 0.9937 - val_loss: 0.0327
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9965 - loss: 0.0239
# Epoch 6: val_loss did not improve from 0.03274
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - accuracy: 0.9965 - loss: 0.0237 - val_accuracy: 0.9937 - val_loss: 0.0409
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9969 - loss: 0.0204
# Epoch 7: val_loss did not improve from 0.03274
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - accuracy: 0.9968 - loss: 0.0207 - val_accuracy: 0.9937 - val_loss: 0.0328
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9963 - loss: 0.0232
# Epoch 8: val_loss did not improve from 0.03274
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.9964 - loss: 0.0229 - val_accuracy: 0.9937 - val_loss: 0.0361
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9962 - loss: 0.0228
# Epoch 9: val_loss did not improve from 0.03274
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 281ms/step - accuracy: 0.9963 - loss: 0.0225 - val_accuracy: 0.9937 - val_loss: 0.0331
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9969 - loss: 0.0186
# Epoch 10: val_loss improved from 0.03274 to 0.03267, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 320ms/step - accuracy: 0.9969 - loss: 0.0189 - val_accuracy: 0.9937 - val_loss: 0.0327
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9965 - loss: 0.0198
# Epoch 11: val_loss improved from 0.03267 to 0.03261, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.9965 - loss: 0.0199 - val_accuracy: 0.9937 - val_loss: 0.0326
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9967 - loss: 0.0190
# Epoch 12: val_loss improved from 0.03261 to 0.03102, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 325ms/step - accuracy: 0.9967 - loss: 0.0191 - val_accuracy: 0.9937 - val_loss: 0.0310
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9968 - loss: 0.0180
# Epoch 13: val_loss improved from 0.03102 to 0.02924, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 0.9968 - loss: 0.0182 - val_accuracy: 0.9937 - val_loss: 0.0292
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9960 - loss: 0.0220
# Epoch 14: val_loss did not improve from 0.02924
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - accuracy: 0.9961 - loss: 0.0216 - val_accuracy: 0.9937 - val_loss: 0.0386
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9967 - loss: 0.0196
# Epoch 15: val_loss improved from 0.02924 to 0.02564, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 0.9966 - loss: 0.0196 - val_accuracy: 0.9937 - val_loss: 0.0256
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9963 - loss: 0.0207
# Epoch 16: val_loss did not improve from 0.02564
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 0.9964 - loss: 0.0205 - val_accuracy: 0.9937 - val_loss: 0.0364
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9964 - loss: 0.0207
# Epoch 17: val_loss improved from 0.02564 to 0.02496, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 0.9964 - loss: 0.0205 - val_accuracy: 0.9937 - val_loss: 0.0250
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9965 - loss: 0.0192
# Epoch 18: val_loss did not improve from 0.02496
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - accuracy: 0.9965 - loss: 0.0190 - val_accuracy: 0.9937 - val_loss: 0.0302
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9962 - loss: 0.0198
# Epoch 19: val_loss did not improve from 0.02496
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - accuracy: 0.9962 - loss: 0.0195 - val_accuracy: 0.9937 - val_loss: 0.0255
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9963 - loss: 0.0179
# Epoch 20: val_loss improved from 0.02496 to 0.02355, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step - accuracy: 0.9964 - loss: 0.0177 - val_accuracy: 0.9937 - val_loss: 0.0236
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9965 - loss: 0.0164
# Epoch 21: val_loss improved from 0.02355 to 0.02174, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.9965 - loss: 0.0164 - val_accuracy: 0.9937 - val_loss: 0.0217
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9967 - loss: 0.0152
# Epoch 22: val_loss improved from 0.02174 to 0.01945, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.9967 - loss: 0.0153 - val_accuracy: 0.9937 - val_loss: 0.0195
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9970 - loss: 0.0143
# Epoch 23: val_loss improved from 0.01945 to 0.01758, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.9969 - loss: 0.0146 - val_accuracy: 0.9937 - val_loss: 0.0176
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9965 - loss: 0.0155
# Epoch 24: val_loss did not improve from 0.01758
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.9965 - loss: 0.0154 - val_accuracy: 0.9937 - val_loss: 0.0187
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9963 - loss: 0.0169
# Epoch 25: val_loss did not improve from 0.01758
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 0.9964 - loss: 0.0169 - val_accuracy: 0.9937 - val_loss: 0.0191
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9969 - loss: 0.0135
# Epoch 26: val_loss improved from 0.01758 to 0.01555, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.9968 - loss: 0.0136 - val_accuracy: 0.9937 - val_loss: 0.0155
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9968 - loss: 0.0123
# Epoch 27: val_loss improved from 0.01555 to 0.01380, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 334ms/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.9937 - val_loss: 0.0138
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9972 - loss: 0.0110
# Epoch 28: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.9971 - loss: 0.0113 - val_accuracy: 0.9937 - val_loss: 0.0138
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9969 - loss: 0.0201
# Epoch 29: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.9968 - loss: 0.0204 - val_accuracy: 0.9937 - val_loss: 0.0202
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9967 - loss: 0.0168
# Epoch 30: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.9967 - loss: 0.0170 - val_accuracy: 0.9937 - val_loss: 0.0225
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9965 - loss: 0.0176
# Epoch 31: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.9965 - loss: 0.0176 - val_accuracy: 0.9937 - val_loss: 0.0155
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9967 - loss: 0.0153
# Epoch 32: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.9967 - loss: 0.0153 - val_accuracy: 0.9937 - val_loss: 0.0171
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9961 - loss: 0.0162
# Epoch 33: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.9962 - loss: 0.0158 - val_accuracy: 0.9937 - val_loss: 0.0176
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9966 - loss: 0.0132
# Epoch 34: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.9966 - loss: 0.0132 - val_accuracy: 0.9938 - val_loss: 0.0138
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.9960 - loss: 0.0138
# Epoch 35: val_loss did not improve from 0.01380
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.9961 - loss: 0.0135 - val_accuracy: 0.9939 - val_loss: 0.0160
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9965 - loss: 0.0123
# Epoch 36: val_loss improved from 0.01380 to 0.01280, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.9965 - loss: 0.0122 - val_accuracy: 0.9950 - val_loss: 0.0128
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.9971 - loss: 0.0100
# Epoch 37: val_loss improved from 0.01280 to 0.01051, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.9971 - loss: 0.0101 - val_accuracy: 0.9958 - val_loss: 0.0105
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9968 - loss: 0.0099
# Epoch 38: val_loss did not improve from 0.01051
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.9968 - loss: 0.0100 - val_accuracy: 0.9957 - val_loss: 0.0118
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9962 - loss: 0.0131
# Epoch 39: val_loss did not improve from 0.01051
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - accuracy: 0.9963 - loss: 0.0128 - val_accuracy: 0.9958 - val_loss: 0.0105
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9968 - loss: 0.0116
# Epoch 40: val_loss did not improve from 0.01051
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - accuracy: 0.9968 - loss: 0.0115 - val_accuracy: 0.9952 - val_loss: 0.0138
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9969 - loss: 0.0103
# Epoch 41: val_loss improved from 0.01051 to 0.00963, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.9969 - loss: 0.0104 - val_accuracy: 0.9963 - val_loss: 0.0096
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9974 - loss: 0.0088
# Epoch 42: val_loss improved from 0.00963 to 0.00942, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.9974 - loss: 0.0091 - val_accuracy: 0.9960 - val_loss: 0.0094
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9969 - loss: 0.0098
# Epoch 43: val_loss improved from 0.00942 to 0.00890, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 353ms/step - accuracy: 0.9969 - loss: 0.0098 - val_accuracy: 0.9964 - val_loss: 0.0089
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9967 - loss: 0.0106
# Epoch 44: val_loss improved from 0.00890 to 0.00864, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 0.9968 - loss: 0.0103 - val_accuracy: 0.9962 - val_loss: 0.0086
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9971 - loss: 0.0084
# Epoch 45: val_loss did not improve from 0.00864
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.9971 - loss: 0.0084 - val_accuracy: 0.9958 - val_loss: 0.0101
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9971 - loss: 0.0081
# Epoch 46: val_loss improved from 0.00864 to 0.00839, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 0.9972 - loss: 0.0081 - val_accuracy: 0.9962 - val_loss: 0.0084
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9970 - loss: 0.0082
# Epoch 47: val_loss did not improve from 0.00839
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.9971 - loss: 0.0081 - val_accuracy: 0.9962 - val_loss: 0.0084
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9977 - loss: 0.0063
# Epoch 48: val_loss improved from 0.00839 to 0.00815, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 358ms/step - accuracy: 0.9977 - loss: 0.0064 - val_accuracy: 0.9961 - val_loss: 0.0082
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9976 - loss: 0.0062
# Epoch 49: val_loss improved from 0.00815 to 0.00803, saving model to unet_best_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 357ms/step - accuracy: 0.9976 - loss: 0.0063 - val_accuracy: 0.9960 - val_loss: 0.0080
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9968 - loss: 0.0080
# Epoch 50: val_loss did not improve from 0.00803
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - accuracy: 0.9969 - loss: 0.0078 - val_accuracy: 0.9960 - val_loss: 0.0104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9970 - loss: 0.0066
# Test Loss: 0.0066, Test Accuracy: 0.9970

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# Prediction and Mask Creation
def create_mask(predictions):
    # Convert predictions to binary mask
    predictions = (predictions > 0.5).astype(np.uint8)
    return predictions

# Load model and predict
best_model = load_model("/kaggle/working/unet_best_model.keras")
predictions = best_model.predict(X_test)

# Create masks from predictions
predicted_masks = create_mask(predictions)

def get_segmented_image(image, mask):
    # Ensure mask has same dimensions as image
    if len(mask.shape) == 2:
        mask = mask[..., np.newaxis]  # add channel dimension if needed
    
    # Multiply image by mask
    segmented = cv2.bitwise_and(image, image, mask=mask.squeeze().astype(np.uint8))
    return segmented

def visualize_results(images, masks, predictions, num_images=5):
    for i in range(num_images):
        img = images[i]
        true_mask = masks[i]
        predicted_mask = predictions[i]
        segmented_img = get_segmented_image(img, predicted_mask)

        plt.figure(figsize=(20, 5))  # wider figure for 4 plots

        # 1. Original Image
        plt.subplot(1, 4, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original Image')
        plt.axis('off')

        # 2. Ground Truth Mask
        plt.subplot(1, 4, 2)
        plt.imshow(true_mask.squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')

        # 3. Predicted Mask
        plt.subplot(1, 4, 3)
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        # 4. Segmented Part
        plt.subplot(1, 4, 4)
        plt.imshow(cv2.cvtColor(segmented_img, cv2.COLOR_BGR2RGB))
        plt.title('Segmented Part')
        plt.axis('off')

        plt.show()

# Visualize results
visualize_results(X_test, y_test, predicted_masks, num_images=5)



# Save predicted masks and segmented images
def save_masks_and_segmented(images, masks, output_dir):
    masks_dir = os.path.join(output_dir, "predicted_masks")
    segmented_dir = os.path.join(output_dir, "segmented_images")
    
    os.makedirs(masks_dir, exist_ok=True)
    os.makedirs(segmented_dir, exist_ok=True)
    
    for i, (img, mask) in enumerate(zip(images, masks)):
        # Save predicted mask
        mask_path = os.path.join(masks_dir, f"pred_mask_{i}.png")
        cv2.imwrite(mask_path, (mask.squeeze() * 255).astype(np.uint8))
        
        # Save segmented image
        segmented_img = get_segmented_image(img, mask)
        
        # Convert to BGR before saving (if your images are in RGB)
        if segmented_img.shape[2] == 3:
            segmented_img_bgr = cv2.cvtColor(segmented_img, cv2.COLOR_RGB2BGR)
        else:
            segmented_img_bgr = segmented_img
        
        segmented_path = os.path.join(segmented_dir, f"segmented_{i}.png")
        cv2.imwrite(segmented_path, segmented_img_bgr)


save_masks_and_segmented(X_test, predicted_masks, output_dir="/kaggle/working/output")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# [ WARN:0@126.719] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.

# %%
while(True):
    continue
