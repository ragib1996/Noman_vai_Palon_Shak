# %%
import numpy as np
import os
import tensorflow as tf
import cv2
import json
import matplotlib.pyplot as plt

print("Hello world.")
# Out:
# 2025-12-15 10:55:15.120757: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765796115.490305      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765796115.609185      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Hello world.

# %%
def find_image_file(base_name, image_path):
    """Find the correct image file (.jpg, .JPG, .jpeg, .JPEG, .png)"""
    exts = [".jpg", ".JPG", ".jpeg", ".JPEG", ".png"]
    for ext in exts:
        file_path = os.path.join(image_path, base_name + ext)
        if os.path.exists(file_path):
            return file_path
    return None

print("Hello world")
# Out:
# Hello world

# %%
import os
import json
import numpy as np
import cv2

def create_mask(json_file, image_shape):
    if json_file is None or not os.path.exists(json_file):
        return None
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except:
        return None
    if 'shapes' not in data or data['shapes'] is None:
        return None

    mask = np.zeros(image_shape[:2], dtype=np.uint8)

    try:
        for shape in data['shapes']:
            points = np.array(shape.get('points', []), dtype=np.int32)
            if len(points) > 2:
                cv2.fillPoly(mask, [points], 255)
    except:
        return None

    return mask


def find_image_file(base_name, image_path):
    """Find the correct image file (.jpg, .JPG, .jpeg, .JPEG, .png)"""
    exts = [".jpg", ".JPG", ".jpeg", ".JPEG", ".png"]
    for ext in exts:
        file_path = os.path.join(image_path, base_name + ext)
        if os.path.exists(file_path):
            return file_path
    return None

print("Hello world")
# Out:
# Hello world

# %%
train_images, valid_images, test_images  = [], [], []
train_masks, valid_masks, test_masks = [], [] , []
test_images_a, test_images_b, test_images_d = [], [], []
test_masks_a, test_masks_b, test_masks_d = [], [], []

image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset/Downy-Mildew(240)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region"


for i in range(0, len(os.listdir(image_path))):

    base_name = f"Downy-Mildew ({i+1})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if i < 192:
        train_images.append(image)
        train_masks.append(mask)
    elif i < 216:
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_d.append(image)
        test_masks_d.append(mask)
        

print("Done.")
# Out:
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region/Downy-Mildew (3).json
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region/Downy-Mildew (21).json
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region/Downy-Mildew (22).json
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region/Downy-Mildew (41).json
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Downy-Mildew(240)/affected_region/Downy-Mildew (44).json
# Done.

# %%
image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset/Anthracnose(102)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Anthracnose(102)/affected_region"


for i in range(0, len(os.listdir(image_path))):

    base_name = f"Anthracnose ({i+1})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if i < 80:
        train_images.append(image)
        train_masks.append(mask)
    elif i < 90:
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_a.append(image)
        test_masks_a.append(mask)

print("Done.")
# Out:
# Done.

# %%
image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset/Bacterial-Spot(752)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Bacterial-Spot(752)/affected_region/Bacterial-Spot(752)"


for i in range(0, len(os.listdir(image_path))):

    base_name = f"Bacterial-Spot ({i+1})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if i < 650:
        train_images.append(image)
        train_masks.append(mask)
    elif i < 675:
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_b.append(image)
        test_masks_b.append(mask)

print("Done.")
# Out:
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Bacterial-Spot(752)/affected_region/Bacterial-Spot(752)/Bacterial-Spot (86).json
# Mask skipped: /kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files_v2/Bacterial-Spot(752)/affected_region/Bacterial-Spot(752)/Bacterial-Spot (91).json
# Done.

# %%
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D,
    BatchNormalization, Activation, Add, Multiply, Concatenate
)
from tensorflow.keras.models import Model

# %%
def conv_block(x, filters):
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def attention_gate(g, x, inter_channels):
    """
    g: decoder feature map
    x: encoder feature map
    """

    g1 = Conv2D(inter_channels, 1, padding="same")(g)
    g1 = BatchNormalization()(g1)

    x1 = Conv2D(inter_channels, 1, padding="same")(x)
    x1 = BatchNormalization()(x1)

    psi = Add()([g1, x1])
    psi = Activation("relu")(psi)

    psi = Conv2D(1, 1, padding="same")(psi)
    psi = BatchNormalization()(psi)
    psi = Activation("sigmoid")(psi)

    return Multiply()([x, psi])

# %%
def Attention_UNet(input_shape=(256, 256, 3), n_classes=1):

    inputs = Input(input_shape)

    # Encoder
    c1 = conv_block(inputs, 64)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = conv_block(p1, 128)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = conv_block(p2, 256)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = conv_block(p3, 512)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = conv_block(p4, 1024)

    # Decoder
    u5 = UpSampling2D((2, 2))(c5)
    a4 = attention_gate(u5, c4, 256)
    u5 = Concatenate()([u5, a4])
    c6 = conv_block(u5, 512)

    u6 = UpSampling2D((2, 2))(c6)
    a3 = attention_gate(u6, c3, 128)
    u6 = Concatenate()([u6, a3])
    c7 = conv_block(u6, 256)

    u7 = UpSampling2D((2, 2))(c7)
    a2 = attention_gate(u7, c2, 64)
    u7 = Concatenate()([u7, a2])
    c8 = conv_block(u7, 128)

    u8 = UpSampling2D((2, 2))(c8)
    a1 = attention_gate(u8, c1, 32)
    u8 = Concatenate()([u8, a1])
    c9 = conv_block(u8, 64)

    # Output
    outputs = Conv2D(n_classes, 1, activation="sigmoid")(c9)

    return Model(inputs, outputs)

# %%
model = Attention_UNet(input_shape=(256, 256, 3), n_classes=1)
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# I0000 00:00:1765796175.901099      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1765796175.901741      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ activation_9[0][… │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    262,400 │ up_sampling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    131,328 │ activation_7[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ add[0][0]         │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32, 1) │        257 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 1) │          4 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32, 1) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ activation_7[0][… │
# │                     │ 512)              │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_12[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ activation_13[0]… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │     65,664 │ up_sampling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     32,896 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 64, 64,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64, 1) │        129 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 1) │          4 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64, 64, 1) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (Multiply)          │ 256)              │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_16[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ activation_17[0]… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │     16,448 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │      8,256 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 128, 128,  │          0 │ add_2[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │         65 │ activation_18[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │          4 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 128, 128,  │          0 │ activation_3[0][… │
# │ (Multiply)          │ 128)              │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_20[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ activation_21[0]… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │      4,128 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 256, 256,  │      2,080 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 256, 256,  │         33 │ activation_22[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │          4 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 256, 256,  │          0 │ activation_1[0][… │
# │ (Multiply)          │ 64)               │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_24[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_25[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,930,037 (121.80 MB)
#  Trainable params: 31,916,333 (121.75 MB)
#  Non-trainable params: 13,704 (53.53 KB)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Preprocess images and masks
image_size = (256, 256)

def preprocess_data(images, masks):
    images_resized = [cv2.resize(img, image_size) for img in images]
    masks_resized = [cv2.resize(mask, image_size) for mask in masks]
    
    images_array = np.array(images_resized) / 255.0
    masks_array = np.array(masks_resized) / 255.0
    
    images_array = images_array.astype(np.float32)
    masks_array = masks_array.astype(np.float32)
    
    masks_array = np.expand_dims(masks_array, axis=-1)  # Ensure correct shape
    
    return images_array, masks_array

# Prepare datasets
X_train, y_train = preprocess_data(train_images, train_masks)
X_valid, y_valid = preprocess_data(valid_images, valid_masks)
X_test, y_test = preprocess_data(test_images, test_masks)
#X_test_a, y_test_a = preprocess_data(test_images_a, test_masks_a)
#X_test_b, y_test_b = preprocess_data(test_images_b, test_masks_b)

# Callbacks
checkpoint = ModelCheckpoint("attention_Unet_semi_final_best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor="val_accuracy", patience=40, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=50,
    batch_size=8,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate on test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765796199.953107     109 service.cc:148] XLA service 0x7a1638002b70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765796199.954389     109 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765796199.954425     109 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765796202.606298     109 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1765796259.192874     109 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 114/115 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8758 - loss: 0.3253
# E0000 00:00:1765796336.715532     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765796337.016082     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765796343.121062     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765796343.350251     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 905ms/step - accuracy: 0.8765 - loss: 0.3239
# Epoch 1: val_accuracy improved from -inf to 0.99561, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 188s 970ms/step - accuracy: 0.8773 - loss: 0.3226 - val_accuracy: 0.9956 - val_loss: 0.1387
# Epoch 2/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.9915 - loss: 0.0604
# Epoch 2: val_accuracy did not improve from 0.99561
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 572ms/step - accuracy: 0.9915 - loss: 0.0604 - val_accuracy: 0.9956 - val_loss: 0.0397
# Epoch 3/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9925 - loss: 0.0368
# Epoch 3: val_accuracy did not improve from 0.99561
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 568ms/step - accuracy: 0.9925 - loss: 0.0368 - val_accuracy: 0.9956 - val_loss: 0.0300
# Epoch 4/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9915 - loss: 0.0337
# Epoch 4: val_accuracy improved from 0.99561 to 0.99561, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 585ms/step - accuracy: 0.9915 - loss: 0.0337 - val_accuracy: 0.9956 - val_loss: 0.0274
# Epoch 5/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9932 - loss: 0.0239
# Epoch 5: val_accuracy did not improve from 0.99561
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9932 - loss: 0.0239 - val_accuracy: 0.9919 - val_loss: 0.1309
# Epoch 6/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9908 - loss: 0.0299
# Epoch 6: val_accuracy improved from 0.99561 to 0.99577, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 585ms/step - accuracy: 0.9908 - loss: 0.0299 - val_accuracy: 0.9958 - val_loss: 0.0192
# Epoch 7/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9927 - loss: 0.0216
# Epoch 7: val_accuracy did not improve from 0.99577
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 568ms/step - accuracy: 0.9927 - loss: 0.0216 - val_accuracy: 0.9952 - val_loss: 0.0176
# Epoch 8/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9930 - loss: 0.0214
# Epoch 8: val_accuracy improved from 0.99577 to 0.99647, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 585ms/step - accuracy: 0.9930 - loss: 0.0214 - val_accuracy: 0.9965 - val_loss: 0.0121
# Epoch 9/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9907 - loss: 0.0251
# Epoch 9: val_accuracy did not improve from 0.99647
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 568ms/step - accuracy: 0.9907 - loss: 0.0251 - val_accuracy: 0.9964 - val_loss: 0.0160
# Epoch 10/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9923 - loss: 0.0204
# Epoch 10: val_accuracy did not improve from 0.99647
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 567ms/step - accuracy: 0.9924 - loss: 0.0204 - val_accuracy: 0.9709 - val_loss: 0.2903
# Epoch 11/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9921 - loss: 0.0221
# Epoch 11: val_accuracy improved from 0.99647 to 0.99673, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 585ms/step - accuracy: 0.9921 - loss: 0.0221 - val_accuracy: 0.9967 - val_loss: 0.0558
# Epoch 12/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9928 - loss: 0.0191
# Epoch 12: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9928 - loss: 0.0191 - val_accuracy: 0.9962 - val_loss: 0.0218
# Epoch 13/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9930 - loss: 0.0181
# Epoch 13: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 568ms/step - accuracy: 0.9930 - loss: 0.0181 - val_accuracy: 0.9957 - val_loss: 0.0155
# Epoch 14/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9924 - loss: 0.0216
# Epoch 14: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9924 - loss: 0.0216 - val_accuracy: 0.9963 - val_loss: 0.0122
# Epoch 15/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9919 - loss: 0.0215
# Epoch 15: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9919 - loss: 0.0215 - val_accuracy: 0.9964 - val_loss: 0.0128
# Epoch 16/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9928 - loss: 0.0199
# Epoch 16: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9928 - loss: 0.0199 - val_accuracy: 0.9962 - val_loss: 0.0128
# Epoch 17/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9930 - loss: 0.0174
# Epoch 17: val_accuracy did not improve from 0.99673
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9930 - loss: 0.0174 - val_accuracy: 0.9965 - val_loss: 0.0165
# Epoch 18/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9920 - loss: 0.0212
# Epoch 18: val_accuracy improved from 0.99673 to 0.99678, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 587ms/step - accuracy: 0.9921 - loss: 0.0212 - val_accuracy: 0.9968 - val_loss: 0.0102
# Epoch 19/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9928 - loss: 0.0185
# Epoch 19: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9928 - loss: 0.0185 - val_accuracy: 0.9965 - val_loss: 0.0148
# Epoch 20/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9930 - loss: 0.0187
# Epoch 20: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9930 - loss: 0.0187 - val_accuracy: 0.9965 - val_loss: 0.0101
# Epoch 21/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9921 - loss: 0.0201
# Epoch 21: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9922 - loss: 0.0201 - val_accuracy: 0.9956 - val_loss: 0.0406
# Epoch 22/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9932 - loss: 0.0181
# Epoch 22: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9932 - loss: 0.0181 - val_accuracy: 0.9959 - val_loss: 0.0118
# Epoch 23/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9933 - loss: 0.0181
# Epoch 23: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9933 - loss: 0.0181 - val_accuracy: 0.9966 - val_loss: 0.0098
# Epoch 24/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9928 - loss: 0.0178
# Epoch 24: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9928 - loss: 0.0178 - val_accuracy: 0.9966 - val_loss: 0.0097
# Epoch 25/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9934 - loss: 0.0165
# Epoch 25: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9934 - loss: 0.0165 - val_accuracy: 0.9966 - val_loss: 0.0105
# Epoch 26/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9940 - loss: 0.0147
# Epoch 26: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9940 - loss: 0.0147 - val_accuracy: 0.9965 - val_loss: 0.0152
# Epoch 27/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9930 - loss: 0.0170
# Epoch 27: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9930 - loss: 0.0170 - val_accuracy: 0.9964 - val_loss: 0.0145
# Epoch 28/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9931 - loss: 0.0173
# Epoch 28: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9931 - loss: 0.0173 - val_accuracy: 0.9964 - val_loss: 0.0109
# Epoch 29/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9927 - loss: 0.0181
# Epoch 29: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9927 - loss: 0.0180 - val_accuracy: 0.9962 - val_loss: 0.0128
# Epoch 30/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9937 - loss: 0.0159
# Epoch 30: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9937 - loss: 0.0159 - val_accuracy: 0.9961 - val_loss: 0.0126
# Epoch 31/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9938 - loss: 0.0157
# Epoch 31: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9938 - loss: 0.0157 - val_accuracy: 0.9959 - val_loss: 0.0138
# Epoch 32/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9934 - loss: 0.0165
# Epoch 32: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9934 - loss: 0.0165 - val_accuracy: 0.9958 - val_loss: 0.0140
# Epoch 33/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9932 - loss: 0.0168
# Epoch 33: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9932 - loss: 0.0168 - val_accuracy: 0.9967 - val_loss: 0.0091
# Epoch 34/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9932 - loss: 0.0168
# Epoch 34: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9932 - loss: 0.0168 - val_accuracy: 0.9954 - val_loss: 0.0467
# Epoch 35/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9937 - loss: 0.0151
# Epoch 35: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9937 - loss: 0.0151 - val_accuracy: 0.9965 - val_loss: 0.0197
# Epoch 36/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9943 - loss: 0.0133
# Epoch 36: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9943 - loss: 0.0133 - val_accuracy: 0.9964 - val_loss: 0.0116
# Epoch 37/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9936 - loss: 0.0154
# Epoch 37: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9936 - loss: 0.0154 - val_accuracy: 0.9960 - val_loss: 0.0136
# Epoch 38/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9938 - loss: 0.0149
# Epoch 38: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9938 - loss: 0.0149 - val_accuracy: 0.9965 - val_loss: 0.0133
# Epoch 39/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9939 - loss: 0.0156
# Epoch 39: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9939 - loss: 0.0156 - val_accuracy: 0.9626 - val_loss: 0.2877
# Epoch 40/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9933 - loss: 0.0181
# Epoch 40: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9933 - loss: 0.0181 - val_accuracy: 0.9961 - val_loss: 0.0189
# Epoch 41/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9934 - loss: 0.0167
# Epoch 41: val_accuracy did not improve from 0.99678
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 65s 569ms/step - accuracy: 0.9934 - loss: 0.0167 - val_accuracy: 0.9952 - val_loss: 0.0213
# Epoch 42/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9933 - loss: 0.0183
# Epoch 42: val_accuracy improved from 0.99678 to 0.99679, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 67s 587ms/step - accuracy: 0.9933 - loss: 0.0183 - val_accuracy: 0.9968 - val_loss: 0.0115
# Epoch 43/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9934 - loss: 0.0171
# Epoch 43: val_accuracy improved from 0.99679 to 0.99688, saving model to attention_Unet_semi_final_best_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 68s 587ms/step - accuracy: 0.9934 - loss: 0.0171 - val_accuracy: 0.9969 - val_loss: 0.0105
# Epoch 44/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9935 - loss: 0.0162
# Epoch 44: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9935 - loss: 0.0162 - val_accuracy: 0.9963 - val_loss: 0.0124
# Epoch 45/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9939 - loss: 0.0148
# Epoch 45: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9939 - loss: 0.0148 - val_accuracy: 0.9963 - val_loss: 0.0134
# Epoch 46/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9941 - loss: 0.0142
# Epoch 46: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9941 - loss: 0.0142 - val_accuracy: 0.9965 - val_loss: 0.0146
# Epoch 47/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9944 - loss: 0.0136
# Epoch 47: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9944 - loss: 0.0136 - val_accuracy: 0.9962 - val_loss: 0.0120
# Epoch 48/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9941 - loss: 0.0145
# Epoch 48: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9941 - loss: 0.0145 - val_accuracy: 0.9960 - val_loss: 0.0315
# Epoch 49/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9939 - loss: 0.0143
# Epoch 49: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9939 - loss: 0.0143 - val_accuracy: 0.9964 - val_loss: 0.0116
# Epoch 50/50
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9941 - loss: 0.0141
# Epoch 50: val_accuracy did not improve from 0.99688
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 66s 570ms/step - accuracy: 0.9941 - loss: 0.0141 - val_accuracy: 0.9966 - val_loss: 0.0102
# 2025-12-15 11:53:50.492716: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-15 11:53:50.687249: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.194737289s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 65s 9s/step - accuracy: 0.9960 - loss: 0.0133
# Test Loss: 0.0116, Test Accuracy: 0.9965

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# Prediction and Mask Creation
def create_mask(predictions):
    # Convert predictions to binary mask
    predictions = (predictions > 0.5).astype(np.uint8)
    return predictions

# Load model and predict
best_model = load_model("/kaggle/working/attention_Unet_semi_final_best_model.keras")
predictions = best_model.predict(X_test)

# Create masks from predictions
predicted_masks = create_mask(predictions)

def get_segmented_image(image, mask):
    # Ensure both are uint8 and mask is single channel
    image_uint8 = (image * 255).astype(np.uint8) if image.dtype != np.uint8 else image
    mask_uint8 = (mask.squeeze() * 255).astype(np.uint8)
    
    # Ensure mask is 2D
    if mask_uint8.ndim == 3:
        mask_uint8 = mask_uint8[..., 0]

    # Apply mask using bitwise_and
    segmented = cv2.bitwise_and(image_uint8, image_uint8, mask=mask_uint8)
    return segmented

def visualize_results(images, masks, predictions, num_images=10):
    for i in range(0, num_images):
        img = images[i]
        true_mask = masks[i]
        predicted_mask = predictions[i]
        segmented_img = get_segmented_image(img, predicted_mask)

        plt.figure(figsize=(20, 5))  # wider figure for 4 plots

        # 1. Original Image
        plt.subplot(1, 4, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original Image')
        plt.axis('off')

        # 2. Ground Truth Mask
        plt.subplot(1, 4, 2)
        plt.imshow(true_mask.squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')

        # 3. Predicted Mask
        plt.subplot(1, 4, 3)
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        # 4. Segmented Part
        plt.subplot(1, 4, 4)
        plt.imshow(cv2.cvtColor(segmented_img, cv2.COLOR_BGR2RGB))
        plt.title('Segmented Part')
        plt.axis('off')

        plt.show()

# Visualize results
visualize_results(X_test, y_test, predicted_masks, num_images=5)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step

# %%
while(True):
    a = 5
