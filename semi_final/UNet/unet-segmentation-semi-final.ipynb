# %%
import numpy as np
import os
import tensorflow as tf
import cv2
import json
import matplotlib.pyplot as plt
import pandas as pd

print("Hello world.")
# Out:
# 2025-12-16 11:28:04.936115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765884485.331916      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765884485.442733      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Hello world.

# %%
def find_image_file(base_name, image_path):
    """Find the correct image file (.jpg, .JPG, .jpeg, .JPEG, .png)"""
    exts = [".jpg", ".JPG", ".jpeg", ".JPEG", ".png"]
    for ext in exts:
        file_path = os.path.join(image_path, base_name + ext)
        if os.path.exists(file_path):
            return file_path
    return None

print("Hello world")
# Out:
# Hello world

# %%
import os
import json
import numpy as np
import cv2

def create_mask(json_file, image_shape):
    if json_file is None or not os.path.exists(json_file):
        return None
    try:
        with open(json_file, 'r') as f:
            data = json.load(f)
    except:
        return None
    if 'shapes' not in data or data['shapes'] is None:
        return None

    mask = np.zeros(image_shape[:2], dtype=np.uint8)

    try:
        for shape in data['shapes']:
            points = np.array(shape.get('points', []), dtype=np.int32)
            if len(points) > 2:
                cv2.fillPoly(mask, [points], 255)
    except:
        return None

    return mask


def find_image_file(base_name, image_path):
    """Find the correct image file (.jpg, .JPG, .jpeg, .JPEG, .png)"""
    exts = [".jpg", ".JPG", ".jpeg", ".JPEG", ".png"]
    for ext in exts:
        file_path = os.path.join(image_path, base_name + ext)
        if os.path.exists(file_path):
            return file_path
    return None

print("Hello world")
# Out:
# Hello world

# %%
train_images, valid_images, test_images  = [], [], []
train_masks, valid_masks, test_masks = [], [] , []
test_images_a, test_images_b, test_images_d = [], [], []
test_masks_a, test_masks_b, test_masks_d = [], [], []

image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset_Original_Data/Malabar_Dataset/Anthracnose(102)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files/Anthracnose(102)/affected_region"
split_file = pd.read_csv("/kaggle/input/malabar-dataset/anthracnose_split.csv")


for i in range(0, len(split_file)):
    used_for = split_file.iloc[i]["used_for"]
    image_no = split_file.iloc[i]["image_no"]
    base_name = f"Anthracnose ({image_no})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if used_for == "training":
        train_images.append(image)
        train_masks.append(mask)
    elif used_for == "validation":
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_a.append(image)
        test_masks_a.append(mask)



print(len(train_images), len(train_masks))
print(len(valid_images), len(valid_masks))
print(len(test_images), len(test_masks))
# Out:
# 80 80
# 10 10
# 12 12

# %%
image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset_Original_Data/Malabar_Dataset/Bacterial-Spot(752)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files/Bacterial-Spot(752)/affected_region/Bacterial-Spot(752)"
split_file = pd.read_csv("/kaggle/input/malabar-dataset/bacterial_spot_split.csv")


for i in range(0, len(split_file)):
    used_for = split_file.iloc[i]["used_for"]
    image_no = split_file.iloc[i]["image_no"]
    base_name = f"Bacterial-Spot ({image_no})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if used_for == "training":
        train_images.append(image)
        train_masks.append(mask)
    elif used_for == "validation":
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_a.append(image)
        test_masks_a.append(mask)


#Bacterial-Spot (1).jpg

print(len(train_images), len(train_masks))
print(len(valid_images), len(valid_masks))
print(len(test_images), len(test_masks))
# Out:
# 680 680
# 85 85
# 89 89

# %%
image_path = "/kaggle/input/malabar-dataset/Malabar_Dataset_Original_Data/Malabar_Dataset/Downy-Mildew(240)"
json_path = "/kaggle/input/annotated-dataset-json-files-version-2/annotated_json_files/Downy-Mildew(240)/affected_region"
split_file = pd.read_csv("/kaggle/input/malabar-dataset/downy_mildew_split.csv")


for i in range(0, len(split_file)):
    used_for = split_file.iloc[i]["used_for"]
    image_no = split_file.iloc[i]["image_no"]
    base_name = f"Downy-Mildew ({image_no})"

    json_file = os.path.join(json_path, base_name + ".json")

    # --- FIND REAL IMAGE FILE ---
    image_file = find_image_file(base_name, image_path)
    if image_file is None:
        print(f"Image missing: {base_name}")
        continue

    image = cv2.imread(image_file)
    if image is None:
        print(f"Failed to read: {image_file}")
        continue

    mask = create_mask(json_file, image.shape)
    if mask is None:
        print(f"Mask skipped: {json_file}")
        continue

    if used_for == "training":
        train_images.append(image)
        train_masks.append(mask)
    elif used_for == "validation":
        valid_images.append(image)
        valid_masks.append(mask)
    else:
        test_images.append(image)
        test_masks.append(mask)
        test_images_a.append(image)
        test_masks_a.append(mask)


#Bacterial-Spot (1).jpg

print(len(train_images), len(train_masks))
print(len(valid_images), len(valid_masks))
print(len(test_images), len(test_masks))
# Out:
# 872 872
# 109 109
# 113 113

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input, concatenate

def build_unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    
    u4 = UpSampling2D((2, 2))(c3)
    u4 = concatenate([u4, c2])
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(u4)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(c4)
    
    u5 = UpSampling2D((2, 2))(c4)
    u5 = concatenate([u5, c1])
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same')(u5)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same')(c5)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c5)
    
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

unet_model = build_unet()
unet_model.summary()
# Out:
# I0000 00:00:1765884541.230233      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1765884541.230932      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 128, 128,  │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 128,  │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 256, 256,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 256, 256,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │         65 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,883,137 (7.18 MB)
#  Trainable params: 1,883,137 (7.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np

# Preprocess images and masks
image_size = (256, 256)

def preprocess_data(images, masks):
    images_resized = [cv2.resize(img, image_size) for img in images]
    masks_resized = [cv2.resize(mask, image_size) for mask in masks]
    
    images_array = np.array(images_resized) / 255.0
    masks_array = np.array(masks_resized) / 255.0
    
    images_array = images_array.astype(np.float32)
    masks_array = masks_array.astype(np.float32)
    
    masks_array = np.expand_dims(masks_array, axis=-1)  # Ensure correct shape
    
    return images_array, masks_array

# Prepare datasets
X_train, y_train = preprocess_data(train_images, train_masks)
X_valid, y_valid = preprocess_data(valid_images, valid_masks)
X_test, y_test = preprocess_data(test_images, test_masks)
#X_test_a, y_test_a = preprocess_data(test_images_a, test_masks_a)
#X_test_b, y_test_b = preprocess_data(test_images_b, test_masks_b)

# Callbacks
checkpoint = ModelCheckpoint("unet_best_model_semi_final.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor="val_accuracy", patience=90, restore_best_weights=True)

# Train the model
history = unet_model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs= 100,
    batch_size=8,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate on test set
test_loss, test_accuracy = unet_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765884551.546461     103 service.cc:148] XLA service 0x77fdfc009be0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765884551.548523     103 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765884551.548546     103 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765884552.214032     103 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1765884578.126150     103 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9926 - loss: 0.0942
# Epoch 1: val_accuracy improved from -inf to 0.99214, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 74s 395ms/step - accuracy: 0.9926 - loss: 0.0938 - val_accuracy: 0.9921 - val_loss: 0.0313
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9923 - loss: 0.0302
# Epoch 2: val_accuracy improved from 0.99214 to 0.99219, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 29s 262ms/step - accuracy: 0.9923 - loss: 0.0302 - val_accuracy: 0.9922 - val_loss: 0.0295
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9920 - loss: 0.0324
# Epoch 3: val_accuracy improved from 0.99219 to 0.99231, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 271ms/step - accuracy: 0.9920 - loss: 0.0323 - val_accuracy: 0.9923 - val_loss: 0.0307
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9923 - loss: 0.0264
# Epoch 4: val_accuracy did not improve from 0.99231
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9923 - loss: 0.0264 - val_accuracy: 0.9923 - val_loss: 0.0280
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9922 - loss: 0.0258
# Epoch 5: val_accuracy did not improve from 0.99231
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 292ms/step - accuracy: 0.9922 - loss: 0.0259 - val_accuracy: 0.9921 - val_loss: 0.0321
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9921 - loss: 0.0316
# Epoch 6: val_accuracy did not improve from 0.99231
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 282ms/step - accuracy: 0.9921 - loss: 0.0316 - val_accuracy: 0.9922 - val_loss: 0.0291
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9925 - loss: 0.0246
# Epoch 7: val_accuracy improved from 0.99231 to 0.99250, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9925 - loss: 0.0246 - val_accuracy: 0.9925 - val_loss: 0.0254
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9934 - loss: 0.0183
# Epoch 8: val_accuracy improved from 0.99250 to 0.99261, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 289ms/step - accuracy: 0.9934 - loss: 0.0183 - val_accuracy: 0.9926 - val_loss: 0.0226
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9924 - loss: 0.0202
# Epoch 9: val_accuracy improved from 0.99261 to 0.99298, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9924 - loss: 0.0202 - val_accuracy: 0.9930 - val_loss: 0.0225
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9918 - loss: 0.0231
# Epoch 10: val_accuracy did not improve from 0.99298
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9918 - loss: 0.0231 - val_accuracy: 0.9928 - val_loss: 0.0216
# Epoch 11/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9927 - loss: 0.0195
# Epoch 11: val_accuracy improved from 0.99298 to 0.99325, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9927 - loss: 0.0195 - val_accuracy: 0.9933 - val_loss: 0.0198
# Epoch 12/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9934 - loss: 0.0179
# Epoch 12: val_accuracy did not improve from 0.99325
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9934 - loss: 0.0179 - val_accuracy: 0.9925 - val_loss: 0.0204
# Epoch 13/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9925 - loss: 0.0198
# Epoch 13: val_accuracy did not improve from 0.99325
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9926 - loss: 0.0198 - val_accuracy: 0.9932 - val_loss: 0.0196
# Epoch 14/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9932 - loss: 0.0186
# Epoch 14: val_accuracy improved from 0.99325 to 0.99333, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9932 - loss: 0.0186 - val_accuracy: 0.9933 - val_loss: 0.0204
# Epoch 15/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9933 - loss: 0.0178
# Epoch 15: val_accuracy did not improve from 0.99333
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9933 - loss: 0.0178 - val_accuracy: 0.9933 - val_loss: 0.0190
# Epoch 16/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9939 - loss: 0.0157
# Epoch 16: val_accuracy did not improve from 0.99333
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9939 - loss: 0.0157 - val_accuracy: 0.9932 - val_loss: 0.0204
# Epoch 17/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0155
# Epoch 17: val_accuracy did not improve from 0.99333
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9944 - loss: 0.0155 - val_accuracy: 0.9933 - val_loss: 0.0196
# Epoch 18/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9931 - loss: 0.0187
# Epoch 18: val_accuracy improved from 0.99333 to 0.99340, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9931 - loss: 0.0187 - val_accuracy: 0.9934 - val_loss: 0.0192
# Epoch 19/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9935 - loss: 0.0176
# Epoch 19: val_accuracy did not improve from 0.99340
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9935 - loss: 0.0176 - val_accuracy: 0.9933 - val_loss: 0.0206
# Epoch 20/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9934 - loss: 0.0188
# Epoch 20: val_accuracy did not improve from 0.99340
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9934 - loss: 0.0188 - val_accuracy: 0.9932 - val_loss: 0.0215
# Epoch 21/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9932 - loss: 0.0178
# Epoch 21: val_accuracy did not improve from 0.99340
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9932 - loss: 0.0178 - val_accuracy: 0.9931 - val_loss: 0.0202
# Epoch 22/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9936 - loss: 0.0163
# Epoch 22: val_accuracy did not improve from 0.99340
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9936 - loss: 0.0164 - val_accuracy: 0.9932 - val_loss: 0.0198
# Epoch 23/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9934 - loss: 0.0170
# Epoch 23: val_accuracy improved from 0.99340 to 0.99342, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9934 - loss: 0.0170 - val_accuracy: 0.9934 - val_loss: 0.0192
# Epoch 24/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9926 - loss: 0.0199
# Epoch 24: val_accuracy did not improve from 0.99342
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9926 - loss: 0.0198 - val_accuracy: 0.9934 - val_loss: 0.0186
# Epoch 25/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0145
# Epoch 25: val_accuracy improved from 0.99342 to 0.99355, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9944 - loss: 0.0145 - val_accuracy: 0.9935 - val_loss: 0.0184
# Epoch 26/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9939 - loss: 0.0174
# Epoch 26: val_accuracy did not improve from 0.99355
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9939 - loss: 0.0174 - val_accuracy: 0.9935 - val_loss: 0.0196
# Epoch 27/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9936 - loss: 0.0178
# Epoch 27: val_accuracy improved from 0.99355 to 0.99363, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9936 - loss: 0.0178 - val_accuracy: 0.9936 - val_loss: 0.0185
# Epoch 28/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9936 - loss: 0.0163
# Epoch 28: val_accuracy improved from 0.99363 to 0.99379, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 289ms/step - accuracy: 0.9936 - loss: 0.0163 - val_accuracy: 0.9938 - val_loss: 0.0181
# Epoch 29/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9940 - loss: 0.0161
# Epoch 29: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9940 - loss: 0.0161 - val_accuracy: 0.9935 - val_loss: 0.0182
# Epoch 30/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9945 - loss: 0.0145
# Epoch 30: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9945 - loss: 0.0145 - val_accuracy: 0.9927 - val_loss: 0.0190
# Epoch 31/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9941 - loss: 0.0169
# Epoch 31: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9941 - loss: 0.0169 - val_accuracy: 0.9937 - val_loss: 0.0181
# Epoch 32/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9939 - loss: 0.0155
# Epoch 32: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9939 - loss: 0.0155 - val_accuracy: 0.9937 - val_loss: 0.0186
# Epoch 33/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9939 - loss: 0.0152
# Epoch 33: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9939 - loss: 0.0152 - val_accuracy: 0.9934 - val_loss: 0.0226
# Epoch 34/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9937 - loss: 0.0167
# Epoch 34: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9937 - loss: 0.0167 - val_accuracy: 0.9937 - val_loss: 0.0182
# Epoch 35/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9943 - loss: 0.0146
# Epoch 35: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9943 - loss: 0.0146 - val_accuracy: 0.9935 - val_loss: 0.0177
# Epoch 36/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9946 - loss: 0.0136
# Epoch 36: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9946 - loss: 0.0136 - val_accuracy: 0.9935 - val_loss: 0.0189
# Epoch 37/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9938 - loss: 0.0162
# Epoch 37: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9938 - loss: 0.0162 - val_accuracy: 0.9936 - val_loss: 0.0177
# Epoch 38/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9949 - loss: 0.0125
# Epoch 38: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9949 - loss: 0.0125 - val_accuracy: 0.9937 - val_loss: 0.0187
# Epoch 39/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0140
# Epoch 39: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9944 - loss: 0.0140 - val_accuracy: 0.9937 - val_loss: 0.0177
# Epoch 40/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0141
# Epoch 40: val_accuracy did not improve from 0.99379
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9944 - loss: 0.0141 - val_accuracy: 0.9931 - val_loss: 0.0241
# Epoch 41/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9932 - loss: 0.0184
# Epoch 41: val_accuracy improved from 0.99379 to 0.99388, saving model to unet_best_model_semi_final.keras
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9932 - loss: 0.0184 - val_accuracy: 0.9939 - val_loss: 0.0174
# Epoch 42/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9951 - loss: 0.0116
# Epoch 42: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9950 - loss: 0.0116 - val_accuracy: 0.9934 - val_loss: 0.0179
# Epoch 43/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0145
# Epoch 43: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9944 - loss: 0.0145 - val_accuracy: 0.9938 - val_loss: 0.0178
# Epoch 44/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9944 - loss: 0.0133
# Epoch 44: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9944 - loss: 0.0133 - val_accuracy: 0.9937 - val_loss: 0.0178
# Epoch 45/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9940 - loss: 0.0160
# Epoch 45: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9940 - loss: 0.0160 - val_accuracy: 0.9938 - val_loss: 0.0171
# Epoch 46/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9940 - loss: 0.0155
# Epoch 46: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9940 - loss: 0.0155 - val_accuracy: 0.9933 - val_loss: 0.0180
# Epoch 47/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9947 - loss: 0.0134
# Epoch 47: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9947 - loss: 0.0134 - val_accuracy: 0.9937 - val_loss: 0.0166
# Epoch 48/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9952 - loss: 0.0116
# Epoch 48: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9952 - loss: 0.0117 - val_accuracy: 0.9938 - val_loss: 0.0177
# Epoch 49/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9944 - loss: 0.0143
# Epoch 49: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9944 - loss: 0.0143 - val_accuracy: 0.9937 - val_loss: 0.0172
# Epoch 50/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9953 - loss: 0.0110
# Epoch 50: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9953 - loss: 0.0110 - val_accuracy: 0.9933 - val_loss: 0.0212
# Epoch 51/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9933 - loss: 0.0179
# Epoch 51: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9933 - loss: 0.0178 - val_accuracy: 0.9937 - val_loss: 0.0190
# Epoch 52/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9950 - loss: 0.0125
# Epoch 52: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9950 - loss: 0.0125 - val_accuracy: 0.9936 - val_loss: 0.0179
# Epoch 53/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9946 - loss: 0.0129
# Epoch 53: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9946 - loss: 0.0129 - val_accuracy: 0.9937 - val_loss: 0.0177
# Epoch 54/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9954 - loss: 0.0105
# Epoch 54: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9954 - loss: 0.0105 - val_accuracy: 0.9935 - val_loss: 0.0180
# Epoch 55/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9950 - loss: 0.0123
# Epoch 55: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9950 - loss: 0.0123 - val_accuracy: 0.9938 - val_loss: 0.0168
# Epoch 56/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9949 - loss: 0.0131
# Epoch 56: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9949 - loss: 0.0131 - val_accuracy: 0.9937 - val_loss: 0.0177
# Epoch 57/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9948 - loss: 0.0129
# Epoch 57: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 289ms/step - accuracy: 0.9948 - loss: 0.0129 - val_accuracy: 0.9937 - val_loss: 0.0169
# Epoch 58/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9947 - loss: 0.0132
# Epoch 58: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9947 - loss: 0.0132 - val_accuracy: 0.9937 - val_loss: 0.0178
# Epoch 59/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9959 - loss: 0.0091
# Epoch 59: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9959 - loss: 0.0091 - val_accuracy: 0.9925 - val_loss: 0.0199
# Epoch 60/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9949 - loss: 0.0126
# Epoch 60: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9949 - loss: 0.0126 - val_accuracy: 0.9935 - val_loss: 0.0197
# Epoch 61/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9947 - loss: 0.0137
# Epoch 61: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9947 - loss: 0.0137 - val_accuracy: 0.9933 - val_loss: 0.0195
# Epoch 62/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9938 - loss: 0.0174
# Epoch 62: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9938 - loss: 0.0174 - val_accuracy: 0.9935 - val_loss: 0.0182
# Epoch 63/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9938 - loss: 0.0153
# Epoch 63: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9938 - loss: 0.0153 - val_accuracy: 0.9936 - val_loss: 0.0189
# Epoch 64/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9949 - loss: 0.0117
# Epoch 64: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9949 - loss: 0.0117 - val_accuracy: 0.9934 - val_loss: 0.0181
# Epoch 65/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9956 - loss: 0.0100
# Epoch 65: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9956 - loss: 0.0100 - val_accuracy: 0.9938 - val_loss: 0.0199
# Epoch 66/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9962 - loss: 0.0083
# Epoch 66: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9962 - loss: 0.0084 - val_accuracy: 0.9935 - val_loss: 0.0187
# Epoch 67/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9951 - loss: 0.0120
# Epoch 67: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 285ms/step - accuracy: 0.9951 - loss: 0.0120 - val_accuracy: 0.9933 - val_loss: 0.0185
# Epoch 68/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9961 - loss: 0.0086
# Epoch 68: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 285ms/step - accuracy: 0.9961 - loss: 0.0086 - val_accuracy: 0.9933 - val_loss: 0.0207
# Epoch 69/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9962 - loss: 0.0083
# Epoch 69: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 285ms/step - accuracy: 0.9962 - loss: 0.0083 - val_accuracy: 0.9937 - val_loss: 0.0202
# Epoch 70/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9963 - loss: 0.0078
# Epoch 70: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 285ms/step - accuracy: 0.9963 - loss: 0.0078 - val_accuracy: 0.9935 - val_loss: 0.0206
# Epoch 71/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9967 - loss: 0.0067
# Epoch 71: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9967 - loss: 0.0067 - val_accuracy: 0.9934 - val_loss: 0.0213
# Epoch 72/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9968 - loss: 0.0063
# Epoch 72: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9968 - loss: 0.0063 - val_accuracy: 0.9932 - val_loss: 0.0242
# Epoch 73/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9971 - loss: 0.0055
# Epoch 73: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9971 - loss: 0.0056 - val_accuracy: 0.9936 - val_loss: 0.0264
# Epoch 74/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9972 - loss: 0.0054
# Epoch 74: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9972 - loss: 0.0054 - val_accuracy: 0.9933 - val_loss: 0.0278
# Epoch 75/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9975 - loss: 0.0045
# Epoch 75: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9975 - loss: 0.0045 - val_accuracy: 0.9934 - val_loss: 0.0287
# Epoch 76/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9974 - loss: 0.0047
# Epoch 76: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9974 - loss: 0.0047 - val_accuracy: 0.9935 - val_loss: 0.0320
# Epoch 77/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9977 - loss: 0.0040
# Epoch 77: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9977 - loss: 0.0040 - val_accuracy: 0.9934 - val_loss: 0.0345
# Epoch 78/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9977 - loss: 0.0039
# Epoch 78: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9977 - loss: 0.0039 - val_accuracy: 0.9934 - val_loss: 0.0351
# Epoch 79/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9978 - loss: 0.0037
# Epoch 79: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9978 - loss: 0.0037 - val_accuracy: 0.9933 - val_loss: 0.0345
# Epoch 80/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9977 - loss: 0.0039
# Epoch 80: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9977 - loss: 0.0039 - val_accuracy: 0.9932 - val_loss: 0.0344
# Epoch 81/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9978 - loss: 0.0036
# Epoch 81: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9978 - loss: 0.0036 - val_accuracy: 0.9932 - val_loss: 0.0359
# Epoch 82/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9980 - loss: 0.0031
# Epoch 82: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9980 - loss: 0.0031 - val_accuracy: 0.9933 - val_loss: 0.0384
# Epoch 83/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9980 - loss: 0.0031
# Epoch 83: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9980 - loss: 0.0031 - val_accuracy: 0.9933 - val_loss: 0.0417
# Epoch 84/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9981 - loss: 0.0029
# Epoch 84: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9981 - loss: 0.0029 - val_accuracy: 0.9932 - val_loss: 0.0418
# Epoch 85/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9983 - loss: 0.0026
# Epoch 85: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9983 - loss: 0.0026 - val_accuracy: 0.9932 - val_loss: 0.0423
# Epoch 86/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9982 - loss: 0.0026
# Epoch 86: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9982 - loss: 0.0026 - val_accuracy: 0.9932 - val_loss: 0.0416
# Epoch 87/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9982 - loss: 0.0026
# Epoch 87: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 288ms/step - accuracy: 0.9982 - loss: 0.0026 - val_accuracy: 0.9933 - val_loss: 0.0344
# Epoch 88/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9971 - loss: 0.0058
# Epoch 88: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9971 - loss: 0.0058 - val_accuracy: 0.9933 - val_loss: 0.0220
# Epoch 89/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9947 - loss: 0.0136
# Epoch 89: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9947 - loss: 0.0136 - val_accuracy: 0.9935 - val_loss: 0.0212
# Epoch 90/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9972 - loss: 0.0055
# Epoch 90: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9972 - loss: 0.0055 - val_accuracy: 0.9934 - val_loss: 0.0291
# Epoch 91/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9977 - loss: 0.0040
# Epoch 91: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9977 - loss: 0.0040 - val_accuracy: 0.9932 - val_loss: 0.0339
# Epoch 92/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9980 - loss: 0.0030
# Epoch 92: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 286ms/step - accuracy: 0.9980 - loss: 0.0030 - val_accuracy: 0.9933 - val_loss: 0.0392
# Epoch 93/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9981 - loss: 0.0026
# Epoch 93: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9981 - loss: 0.0026 - val_accuracy: 0.9933 - val_loss: 0.0447
# Epoch 94/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9983 - loss: 0.0022
# Epoch 94: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9983 - loss: 0.0022 - val_accuracy: 0.9933 - val_loss: 0.0459
# Epoch 95/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9984 - loss: 0.0020
# Epoch 95: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9984 - loss: 0.0020 - val_accuracy: 0.9934 - val_loss: 0.0495
# Epoch 96/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9984 - loss: 0.0019
# Epoch 96: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9984 - loss: 0.0019 - val_accuracy: 0.9933 - val_loss: 0.0500
# Epoch 97/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9985 - loss: 0.0017
# Epoch 97: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9985 - loss: 0.0017 - val_accuracy: 0.9934 - val_loss: 0.0538
# Epoch 98/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9985 - loss: 0.0018
# Epoch 98: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9985 - loss: 0.0018 - val_accuracy: 0.9933 - val_loss: 0.0528
# Epoch 99/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9985 - loss: 0.0017
# Epoch 99: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9985 - loss: 0.0017 - val_accuracy: 0.9933 - val_loss: 0.0506
# Epoch 100/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9985 - loss: 0.0017
# Epoch 100: val_accuracy did not improve from 0.99388
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - accuracy: 0.9985 - loss: 0.0017 - val_accuracy: 0.9933 - val_loss: 0.0537
# 2025-12-16 12:22:20.554705: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-16 12:22:20.801079: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.246675086s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - accuracy: 0.9939 - loss: 0.0161
# Test Loss: 0.0140, Test Accuracy: 0.9946

# %%
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# Prediction and Mask Creation
def create_mask(predictions):
    # Convert predictions to binary mask
    predictions = (predictions > 0.5).astype(np.uint8)
    return predictions

# Load model and predict
best_model = load_model("/kaggle/working/unet_best_model_semi_final.keras")
predictions = best_model.predict(X_test)

# Create masks from predictions
predicted_masks = create_mask(predictions)

def get_segmented_image(image, mask):
    # Ensure both are uint8 and mask is single channel
    image_uint8 = (image * 255).astype(np.uint8) if image.dtype != np.uint8 else image
    mask_uint8 = (mask.squeeze() * 255).astype(np.uint8)
    
    # Ensure mask is 2D
    if mask_uint8.ndim == 3:
        mask_uint8 = mask_uint8[..., 0]

    # Apply mask using bitwise_and
    segmented = cv2.bitwise_and(image_uint8, image_uint8, mask=mask_uint8)
    return segmented

def visualize_results(images, masks, predictions, num_images=10):
    for i in range(0, num_images):
        img = images[i]
        true_mask = masks[i]
        predicted_mask = predictions[i]
        segmented_img = get_segmented_image(img, predicted_mask)

        plt.figure(figsize=(20, 5))  # wider figure for 4 plots

        # 1. Original Image
        plt.subplot(1, 4, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original Image')
        plt.axis('off')

        # 2. Ground Truth Mask
        plt.subplot(1, 4, 2)
        plt.imshow(true_mask.squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')

        # 3. Predicted Mask
        plt.subplot(1, 4, 3)
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        # 4. Segmented Part
        plt.subplot(1, 4, 4)
        plt.imshow(cv2.cvtColor(segmented_img, cv2.COLOR_BGR2RGB))
        plt.title('Segmented Part')
        plt.axis('off')

        plt.show()

# Visualize results
visualize_results(X_test, y_test, predicted_masks, num_images=10)



# Save predicted masks and segmented images
def save_masks_and_segmented(images, masks, output_dir):
    masks_dir = os.path.join(output_dir, "predicted_masks")
    segmented_dir = os.path.join(output_dir, "segmented_images")
    
    os.makedirs(masks_dir, exist_ok=True)
    os.makedirs(segmented_dir, exist_ok=True)
    
    for i, (img, mask) in enumerate(zip(images, masks)):
        # Convert to proper format
        img_uint8 = (img * 255).astype(np.uint8) if img.dtype != np.uint8 else img
        mask_uint8 = (mask.squeeze() * 255).astype(np.uint8)
        
        # Save predicted mask
        mask_path = os.path.join(masks_dir, f"pred_mask_{i}.png")
        cv2.imwrite(mask_path, mask_uint8)
        
        # Create segmented image
        segmented_img = get_segmented_image(img_uint8, mask)
        
        # Ensure color format before saving
        segmented_bgr = segmented_img
        #segmented_bgr = cv2.cvtColor(segmented_img , cv2.COLOR_RGB2BGR)
        segmented_path = os.path.join(segmented_dir, f"segmented_{i}.png")
        cv2.imwrite(segmented_path, segmented_bgr)


save_masks_and_segmented(X_test, predicted_masks, output_dir="/kaggle/working/output")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step

# %%
def visualize_results(images, masks, predictions, num_images=5):
    for i in range(0, num_images):
        img = images[i]
        true_mask = masks[i]
        predicted_mask = predictions[i]
        segmented_img = get_segmented_image(img, predicted_mask)

        plt.figure(figsize=(20, 5))  # wider figure for 4 plots

        # 1. Original Image
        plt.subplot(1, 4, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original Image')
        plt.axis('off')

        # 2. Ground Truth Mask
        plt.subplot(1, 4, 2)
        plt.imshow(true_mask.squeeze(), cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')

        # 3. Predicted Mask
        plt.subplot(1, 4, 3)
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        # 4. Segmented Part
        plt.subplot(1, 4, 4)
        plt.imshow(cv2.cvtColor(segmented_img, cv2.COLOR_BGR2RGB))
        plt.title('Segmented Part')
        plt.axis('off')

        plt.show()

# Visualize results
#visualize_results(X_test_b, y_test_b, predicted_masks, num_images=5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score, f1_score

def calculate_metrics(y_true, y_pred):
    """
    Calculates IoU, Dice coefficient, and pixel accuracy.
    """
    iou_scores = []
    dice_scores = []
    pixel_accuracies = []
    
    for true, pred in zip(y_true, y_pred):
        # Convert to binary (threshold at 0.5)
        true = (true > 0.5).astype(np.uint8).flatten()
        pred = (pred > 0.5).astype(np.uint8).flatten()
        
        # Compute IoU (Jaccard Index)
        iou = jaccard_score(true, pred, average='binary')
        iou_scores.append(iou)
        
        # Compute Dice Coefficient
        dice = f1_score(true, pred, average='binary')
        dice_scores.append(dice)
        
        # Compute Pixel Accuracy
        pixel_acc = np.mean(true == pred)
        pixel_accuracies.append(pixel_acc)
    
    return np.mean(iou_scores), np.mean(dice_scores), np.mean(pixel_accuracies)

# Ensure binary masks
y_test_bin = (y_test > 0.5).astype(np.uint8)
predicted_masks_bin = (predicted_masks > 0.5).astype(np.uint8)

# Compute metrics for segmentation results
iou, dice, pixel_acc = calculate_metrics(y_test_bin, predicted_masks_bin)

print(f"Mean IoU: {iou:.4f}")
print(f"Mean Dice Coefficient: {dice:.4f}")
print(f"Mean Pixel Accuracy: {pixel_acc:.4f}")

# Visualizing metric distributions
def plot_metric_distributions(y_true, y_pred):
    """
    Plots histograms for IoU, Dice coefficient, and Pixel Accuracy.
    """
    iou_scores = []
    dice_scores = []
    pixel_accuracies = []
    
    for true, pred in zip(y_true, y_pred):
        true = true.flatten()
        pred = pred.flatten()
        
        iou_scores.append(jaccard_score(true, pred, average='binary'))
        dice_scores.append(f1_score(true, pred, average='binary'))
        pixel_accuracies.append(np.mean(true == pred))
    
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    plt.hist(iou_scores, bins=20, color='blue', alpha=0.7)
    plt.xlabel("IoU Score")
    plt.ylabel("Frequency")
    plt.title("IoU Distribution")
    
    plt.subplot(1, 3, 2)
    plt.hist(dice_scores, bins=20, color='green', alpha=0.7)
    plt.xlabel("Dice Coefficient")
    plt.ylabel("Frequency")
    plt.title("Dice Coefficient Distribution")
    
    plt.subplot(1, 3, 3)
    plt.hist(pixel_accuracies, bins=20, color='red', alpha=0.7)
    plt.xlabel("Pixel Accuracy")
    plt.ylabel("Frequency")
    plt.title("Pixel Accuracy Distribution")
    
    plt.show()

# Plot metric distributions (Pass binary masks)
plot_metric_distributions(y_test_bin, predicted_masks_bin)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# Mean IoU: 0.4183
# Mean Dice Coefficient: 0.5546
# Mean Pixel Accuracy: 0.9952
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))

# %%
while(True):
    continue
